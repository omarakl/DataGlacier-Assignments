# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_1 = pd.read_csv('Customer_ID.csv')
data_2 = pd.read_csv('Transaction_ID.csv')
cab_data = pd.read_csv('Cab_Data.csv')

# %%
# merging 'customer_data' and 'transaction_data'
customer_data = pd.merge(data_1, data_2, how='inner')

# %%
customer_data.dropna(inplace = True) # dropping NaN values

# %%
customer_data.drop_duplicates()  # drop duplicates
# Out:
#         Customer ID  Gender  Age  Income (USD/Month)  Transaction ID  \
# 0             29290    Male   28               10813        10000011
# 1             29290    Male   28               10813        10351127
# 2             29290    Male   28               10813        10412921
# 3             27703    Male   27                9237        10000012
# 4             27703    Male   27                9237        10320494
# ...             ...     ...  ...                 ...             ...
# 440093        12490    Male   33               18713        10439799
# 440094        14971    Male   30               15346        10439820
# 440095        41414    Male   38                3960        10439838
# 440096        41677    Male   23               19454        10439840
# 440097        39761  Female   32               10128        10439846
#
#        Payment_Mode
# 0              Card
# 1              Cash
# 2              Card
# 3              Card
# 4              Card
# ...

# %%
# Showing the number of males and females
sns.countplot(x='Gender', data=customer_data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(13, 6))
plt.xticks(rotation=45)
ax = sns.countplot(x='Age', data=customer_data, palette='viridis', saturation=0.75, width=0.9)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=7, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# <ipython-input-84-016a0ba9f8f0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Age', data=customer_data, palette='viridis', saturation=0.75, width=0.9)

# %%
sns.countplot(x='Company', data=cab_data)

# Add labels and title
plt.xlabel('Comapany')
plt.ylabel('Count')
plt.title('Number users of each cab company')

# Show the plot
plt.show()
